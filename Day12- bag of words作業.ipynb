# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
import jieba
whole_words = []

for sentence in corpus:
    tokenized_sentence = jieba.tokenize(sentence,)
    for word in tokenized_sentence:
        if word[0] not in whole_words: #避免重複
            whole_words.append(word[0])
whole_words.remove(' ')
print(whole_words)
# Out:
# ['Wow', '...', 'Loved', 'this', 'place', '.', 'Crust', 'is', 'not', 'good', 'Not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty', 'Stopped', 'by', 'during', 'late', 'May', 'bank', 'holiday', 'off', 'Rick', 'Steve', 'recommendation', 'loved', 'it', 'The', 'selection', 'on', 'menu', 'great', 'so', 'were', 'prices', 'Now', 'I', 'am', 'getting', 'angry', 'want', 'my', 'damn', 'pho', 'Honeslty', 'didn', "'", 't', 'taste', 'THAT', 'fresh', ')', 'potatoes', 'like', 'rubber', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer', 'fries', 'too', 'A', 'touch', 'Service', 'very', 'prompt', 'Would', 'go', 'back', 'cashier', 'no', 'care', 'what', 'ever', 'to', 'say', 'still', 'ended', 'wayyy', 'overpriced', 'tried', 'Cape', 'Cod', 'ravoli', ',', 'chicken', 'with', 'cranberry', 'mmmm', '!', 'disgusted', 'because', 'pretty', 'sure', 'that', 'human', 'hair', 'shocked', 'signs', 'indicate', 'cash', 'only', 'Highly', 're
# ...

# %% [markdown]
# ### 移除重複單字

# %%
print('共有{}個單字'.format(len(whole_words))) #共有2356個單字
# Out:
# 共有2355個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n=n+1

# %%
word_index
# Out:
# {'Wow': 0,
#  '...': 1,
#  'Loved': 2,
#  'this': 3,
#  'place': 4,
#  '.': 5,
#  'Crust': 6,
#  'is': 7,
#  'not': 8,
#  'good': 9,
#  'Not': 10,
#  'tasty': 11,
#  'and': 12,
#  'the': 13,
#  'texture': 14,
#  'was': 15,
#  'just': 16,
#  'nasty': 17,
#  'Stopped': 18,
#  'by': 19,
#  'during': 20,
#  'late': 21,
#  'May': 22,
#  'bank': 23,
#  'holiday': 24,
#  'off': 25,
#  'Rick': 26,
#  'Steve': 27,
#  'recommendation': 28,
#  'loved': 29,
#  'it': 30,
#  'The': 31,
#  'selection': 32,
#  'on': 33,
#  'menu': 34,
#  'great': 35,
#  'so': 36,
#  'were': 37,
#  'prices': 38,
#  'Now': 39,
#  'I': 40,
#  'am': 41,
#  'getting': 42,
#  'angry': 43,
#  'want': 44,
#  'my': 45,
#  'damn': 46,
#  'pho': 47,
#  'Honeslty': 48,
#  'didn': 49,
#  "'": 50,
#  't': 51,
#  'taste': 52,
#  'THAT': 53,
#  'fresh': 54,
#  ')': 55,
#  'potatoes': 56,
#  'like': 57,
#  'rubber': 58,
#  'you': 59,
#  'could': 60,
#  'tell': 61,
#  'they': 62,
#  'had': 63,
#  'been': 64,
#  'made': 65,
# ...

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: 'Not',
#  11: 'tasty',
#  12: 'and',
#  13: 'the',
#  14: 'texture',
#  15: 'was',
#  16: 'just',
#  17: 'nasty',
#  18: 'Stopped',
#  19: 'by',
#  20: 'during',
#  21: 'late',
#  22: 'May',
#  23: 'bank',
#  24: 'holiday',
#  25: 'off',
#  26: 'Rick',
#  27: 'Steve',
#  28: 'recommendation',
#  29: 'loved',
#  30: 'it',
#  31: 'The',
#  32: 'selection',
#  33: 'on',
#  34: 'menu',
#  35: 'great',
#  36: 'so',
#  37: 'were',
#  38: 'prices',
#  39: 'Now',
#  40: 'I',
#  41: 'am',
#  42: 'getting',
#  43: 'angry',
#  44: 'want',
#  45: 'my',
#  46: 'damn',
#  47: 'pho',
#  48: 'Honeslty',
#  49: 'didn',
#  50: "'",
#  51: 't',
#  52: 'taste',
#  53: 'THAT',
#  54: 'fresh',
#  55: ')',
#  56: 'potatoes',
#  57: 'like',
#  58: 'rubber',
#  59: 'you',
#  60: 'could',
#  61: 'tell',
#  62: 'they',
#  63: 'had',
#  64: 'been',
#  65: 'made',
# ...

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.repeat(0,len(word_index_dic)) #創建一個vector(向量)
    for word in jieba.tokenize(sentence,):
        if word[0] in whole_words:
            index = word_index_dic[word[0]]
            vector[index] += 1 
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# Wow 0
# ... 1
# Loved 2
# this 3
# place 4
# . 5
# array([1, 1, 1, ..., 0, 0, 0])
